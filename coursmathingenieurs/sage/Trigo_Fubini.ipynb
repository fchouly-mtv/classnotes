# %%
f = cos(x)^6
f.reduce_trig()
# Out:
# 1/32*cos(6*x) + 3/16*cos(4*x) + 15/32*cos(2*x) + 5/16

# %%
f = cos(x/2)^4
f.reduce_trig()
# Out:
# 1/8*cos(2*x) + 1/2*cos(x) + 3/8

# %%
f=cos(x)^2
f.reduce_trig()
# Out:
# 1/2*cos(2*x) + 1/2

# %%
f=cos(x/2)^4*cos(x)^2
f.reduce_trig()
# Out:
# 1/32*cos(4*x) + 1/8*cos(3*x) + 1/4*cos(2*x) + 3/8*cos(x) + 7/32

# %%
f=sin(x)^4
f.reduce_trig()
# Out:
# 1/8*cos(4*x) - 1/2*cos(2*x) + 3/8

# %%
var('alpha')
var('y')
assume(y>0)
assume(y<pi/2)
assume(alpha>0)
assume(alpha<1)
ei=integrate(1/(1+2*alpha*x+x^2),x,0,infinity)

# %%
ei(alpha=cos(alpha)).simplify_trig()
# Out:
# arctan(abs(sin(alpha))/cos(alpha))/abs(sin(alpha))

# %%
N(ei(alpha=cos(pi/4)))
# Out:
# 0.685058233991111

# %%
N(pi/4/(sin(pi/4)))
# Out:
# 1.11072073453959
